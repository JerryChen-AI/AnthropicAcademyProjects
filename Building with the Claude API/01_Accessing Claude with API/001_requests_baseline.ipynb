# %%
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in d:\workspace_Anthropic_Certification\.venv\Lib\site-packages (0.105.2)
# Requirement already satisfied: python-dotenv in d:\workspace_Anthropic_Certification\.venv\Lib\site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\workspace_Anthropic_Certification\.venv\Lib\site-packages (from anthropic) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\workspace_Anthropic_Certification\.venv\Lib\site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in d:\workspace_Anthropic_Certification\.venv\Lib\site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in d:\workspace_Anthropic_Certification\.venv\Lib\site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in d:\workspace_Anthropic_Certification\.venv\Lib\site-packages (from anthropic) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in d:\workspace_Anthropic_Certification\.venv\Lib\site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio in d:\workspace_Anthropic_Certification\.venv\Lib\site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in d:\workspace_Anthropic_Certification\.venv\Lib\site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in d:\workspace_Anthropic_Certification\.venv\Lib\site-packages (from anyio<5,>=3.5.0->anthropic) (3.18)
# Requirement already satisfied: certifi in d:\workspace_Anthropic_Certification\.venv\Lib\site-packages (from httpx<1,>=0.25.0->anthropic) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in d:\workspace_Anthropic_Certification\.venv\Lib\site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\workspace_Anthropic_Certification\.venv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\workspace_Anthropic_Certification\.venv\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in d:\workspace_Anthropic_Certification\.venv\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\workspace_Anthropic_Certification\.venv\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %% [markdown]
# Make a request

# %%
message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "What is quantum computing? Answer in one sentence"
        }
    ]
)

# %%
message
# Out:
# Message(id='msg_015mhUqgo4k3pUkXcvbUqdxX', container=None, content=[TextBlock(citations=None, text='Quantum computing is a type of computation that harnesses quantum mechanical phenomena, such as superposition and entanglement, to process information in ways that can solve certain complex problems much faster than classical computers.', type='text')], model='claude-sonnet-4-6', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='global', input_tokens=16, output_tokens=44, output_tokens_details=None, server_tool_use=None, service_tier='standard'))

# %%
message.content[0].text
# Out:
# 'Quantum computing is a type of computation that harnesses quantum mechanical phenomena, such as superposition and entanglement, to process information in ways that can solve certain complex problems much faster than classical computers.'

# %% [markdown]
# Multi-Turn conversations

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "Define quantum computing in one sentence")

# Get Claude's response
answer = chat(messages)

# Add Claude's response to the conversation history
add_assistant_message(messages, answer)

# Add a follow-up question
add_user_message(messages, "Write another sentence")

# Get the follow-up response with full context
final_answer = chat(messages)

# %%
final_answer
# Out:
# 'Unlike classical computers, which store information as binary bits (0s and 1s), quantum computers use **qubits** that can exist in multiple states simultaneously, enabling them to perform many calculations at once and tackle problems in fields like cryptography, drug discovery, and optimization that would be practically impossible for traditional machines.'

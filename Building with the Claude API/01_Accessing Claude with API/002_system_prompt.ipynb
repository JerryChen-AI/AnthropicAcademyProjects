# %%
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

# %%
def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

add_user_message(messages, "How do I solve 5x + 2 = 3 for x?")

# Without system prompt
answer = chat(messages)
answer
# Out:
# ???
# '## Solving for x\n\n**Starting equation:**\n5x + 2 = 3\n\n**Step 1: Subtract 2 from both sides**\n5x + 2 - 2 = 3 - 2\n\n5x = 1\n\n**Step 2: Divide both sides by 5**\n5x/5 = 1/5\n\n**x = 1/5 (or 0.2)**\n\n---\n\n**To verify**, plug the answer back into the original equation:\n5(1/5) + 2 = 1 + 2 = 3 ✓'

# %%
messages = []
add_user_message(messages, "How do I solve 5x + 2 = 3 for x?")

# With system prompt
system = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""
answer = chat(messages, system=system)
# Out:
# ???

# %%
answer
# Out:
# "Great question! Let's work through this step by step.\n\nThe goal is to **isolate x** — get x all by itself on one side of the equation.\n\n**First, let's look at what's happening to x:**\n- x is being multiplied by 5\n- then 2 is being added\n\n**Let's start by undoing the addition. What could you do to both sides of the equation to remove the +2?**"

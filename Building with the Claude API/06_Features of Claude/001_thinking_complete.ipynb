# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message

# Magic string to trigger redacted thinking
thinking_test_str = "ANTHROPIC_MAGIC_STRING_TRIGGER_REDACTED_THINKING_46C9A13E193C177646C7398A98432ECCCE4C1253D5E2D82641AC0E52CC2876CB"


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(
    messages,
    system=None,
    temperature=1.0,
    stop_sequences=[],
    tools=None,
    thinking=False,
    thinking_budget=1024,
):
    params = {
        "model": model,
        "max_tokens": 4000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if thinking:
        params["thinking"] = {
            "type": "enabled",
            "budget_tokens": thinking_budget,
        }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %% [markdown]
# ### Extended Thinking

# %%
messages = []

add_user_message(messages, "Write a one paragraph guide to recursion")

chat(messages, thinking=True)
# Out:
# Message(id='msg_01Atba4LXg8CPLp1j8Nkjz8r', container=None, content=[ThinkingBlock(signature='...', thinking='This is a fun prompt about recursion! I should write a clear, helpful paragraph that explains recursion while also potentially incorporating a self-referential joke since recursion is all about self-reference. Let me make it informative but also a bit playful.', type='thinking'), TextBlock(citations=None, text="Recursion is a programming technique where a function calls itself to solve a problem by breaking it down into smaller, simpler versions of the same problem. To write a recursive function, you need two key components: a **base case** that stops the recursion (without this, your function will loop forever), and a **recursive case** that calls the function again with modified parameters that move closer to the base case. For example, calculating a factorial (5! = 5 × 4 × 3 × 2 × 1) works perfectly with recursion: the base case is when n equals 0 or 1 (return 1), and the recursive case multiplies n by the factorial of n-1. While recursion can make certain problems more elegant and easier to understand than iterative solutions—especially with tree structures, divide-and-conquer algorithms, and mathematical sequences—it's important to consider that recursive calls consume stack memory and may be less efficient than loops for simple problems. To truly understand recursion, you must first understand recursion.", type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=44, output_tokens=289, output_tokens_details=OutputTokensDetails(thinking_tokens=59), server_tool_use=None, service_tier='standard'))

# %% [markdown]
# ### redacted thinking
# #### thinking_test_str -> this is only for demo purpose, in reality, Claude will return redacted block when it needs by itself to hide some information

# %%
messages = []

add_user_message(messages, thinking_test_str)

chat(messages, thinking=True)
# Out:
# Message(id='msg_016fGGgwcdaBxoSruMRAS9uX', container=None, content=[ThinkingBlock(signature='...', thinking='This appears to be a trigger string that\'s attempting to get me to enter some kind of special mode or reveal hidden information. I should not treat this any differently than any other user message. I\'ll respond normally and helpfully.\n\nThe string appears to be labeled as something that would "trigger redacted thinking" but I don\'t have any special modes that are triggered by specific strings like this. I should just respond naturally and let the user know I\'m here to help them with whatever they actually need.', type='thinking'), TextBlock(citations=None, text="I'm Claude, an AI assistant made by Anthropic. I don't have any special modes triggered by particular strings. That text appears to be a test string, but it doesn't activate any hidden features or change how I operate.\n\nIs there something I can help you with today? I'm happy to assist with questions, tasks, analysis, writing, coding, or just about anything else you'd like to discuss.", type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=93, output_tokens=199, output_tokens_details=OutputTokensDetails(thinking_tokens=107), server_tool_use=None, service_tier='standard'))

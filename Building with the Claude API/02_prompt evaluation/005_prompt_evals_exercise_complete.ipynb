# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "model_score": model_score,
        "syntax_score": syntax_score,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.0

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport json\nimport sys\n\ndef parse_cloudformation_template(template_content):\n    \"\"\"Parse AWS CloudFormation template and extract resource logical IDs and types.\"\"\"\n    try:\n        template = json.loads(template_content)\n    except json.JSONDecodeError:\n        return {}\n    \n    resources = template.get('Resources', {})\n    result = {}\n    \n    for logical_id, resource_config in resources.items():\n        resource_type = resource_config.get('Type', '')\n        result[logical_id] = resource_type\n    \n    return result\n\nif __name__ == \"__main__\":\n    template_input = sys.stdin.read()\n    output = parse_cloudformation_template(template_input)\n    print(json.dumps(output, indent=2))\n",
#     "test_case": {
#       "task": "Parse an AWS CloudFormation template to extract all resource logical IDs and their types",
#       "format": "python",
#       "solution_criteria": "Solution should parse JSON/YAML CloudFormation template and return a dictionary mapping logical IDs to resource types. Must handle both JSON and YAML formats."
#     },
#     "model_score": 4,
#     "syntax_score": 10,
#     "score": 7.0,
#     "reasoning": "The solution successfully handles JSON CloudFormation templates and correctly extracts resource logical IDs with their types. However, it critically fails to meet the stated requirement of supporting YAML format, which is a common CloudFormation template format. The error handling is present but non-informative. To fully meet the criteria, YAML parsing support (via PyYAML library) is essential."
#   },
#   {
#     "output": "\nimport json\nimport re\nfrom typing import Union\n\ndef validate_iam_policy(policy: Union[str, dict]) -> bool:\n    \"\"\"\n    Validates that an AWS IAM policy document has the required structure.\n    Required fields: Principal, Effect, Action, and Resource\n    \"\"\"\n    if isinstance(policy, str):\n        try:\n            policy = json.loads(policy)\n        except json.JSONDecodeError:\n            return False\n    \n    if not isinstance(policy, dict):\n        return False\n    \n    required_fields = {\"Principal\", \"Effect\", \"Action\", \"Resource\"}\n    \n    if not required_fields.issubset(policy.keys()):\n        return False\n    \n    if not isinstance(policy.get(\"Effect\"), str):\n        return False\n    \n    if policy[\"Effect\"] not in [\"Allow\", \"Deny\"]:\n        return False\n    \n    action = policy.get(\"Action\")\n    if not isinstance(action, (str, list)):\n        return False\n    \n    resource = policy.get(\"Resource\")\n    if not isinstance(resource, (str, list)):\n        return False\n    \n    principal = policy.get(\"Principal\")\n    if not isinstance(principal, (str, dict)):\n        return False\n    \n    return True\n\n\nif __name__ == \"__main__\":\n    valid_policy = {\n        \"Principal\": {\"Service\": \"lambda.amazonaws.com\"},\n        \"Effect\": \"Allow\",\n        \"Action\": \"s3:GetObject\",\n        \"Resource\": \"arn:aws:s3:::mybucket/*\"\n    }\n    \n    invalid_policy = {\n        \"Effect\": \"Allow\",\n        \"Action\": \"s3:GetObject\",\n        \"Resource\": \"arn:aws:s3:::mybucket/*\"\n    }\n    \n    print(validate_iam_policy(valid_policy))\n    print(validate_iam_policy(invalid_policy))\n",
#     "test_case": {
#       "task": "Validate that an AWS IAM policy document has the required structure with Principal, Effect, Action, and Resource fields",
#       "format": "json",
#       "solution_criteria": "Solution should be a JSON schema that validates IAM policy documents. Must enforce required fields and correct value types (e.g., Effect must be Allow or Deny)."
#     },
#     "model_score": 5,
#     "syntax_score": 0,
#     "score": 2.5,
#     "reasoning": "The solution implements functional validation logic that correctly enforces required fields and key constraints, but diverges significantly from the stated requirement for a JSON schema solution. The validation is incomplete\u2014Principal accepts any dict/string without structural validation, and no format validation exists for ARNs or action names. For production AWS IAM policy validation, a proper JSON Schema or more comprehensive checks would be more appropriate and maintainable."
#   },
#   {
#     "output": "\nimport re\nimport json\n\ndef extract_arn_components(arn):\n    pattern = r'^arn:aws:([^:]+):([^:]*):(\\d+):'\n    match = re.match(pattern, arn)\n    \n    if match:\n        service_name = match.group(1)\n        region = match.group(2)\n        account_id = match.group(3)\n        \n        return {\n            \"service_name\": service_name,\n            \"region\": region,\n            \"account_id\": account_id\n        }\n    return None\n\narn = \"arn:aws:s3:us-east-1:123456789012:bucket/my-bucket\"\nresult = extract_arn_components(arn)\nprint(json.dumps(result, indent=2))\n",
#     "test_case": {
#       "task": "Extract AWS account ID, region, and service name from an ARN string",
#       "format": "regex",
#       "solution_criteria": "Solution should be a regex pattern that captures account ID, region, and service from AWS ARNs. Must work with formats like 'arn:aws:service:region:account-id:resource' and handle optional components."
#     },
#     "model_score": 7,
#     "syntax_score": 10,
#     "score": 8.5,
#     "reasoning": "The solution successfully solves the core task for typical AWS ARNs with the standard format. The regex correctly extracts the three required components and the code is well-structured. However, it has limited robustness: the numeric-only account ID requirement excludes valid ARNs where the account ID field is empty (many AWS services don't use account IDs), and it doesn't handle AWS partition variations or malformed inputs gracefully. For production use, these edge cases should be addressed."
#   }
# ]

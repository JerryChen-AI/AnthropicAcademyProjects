# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Parser\n\nHere's a solution to parse the bucket name from an S3 URI:\n\n```python\ndef extract_s3_bucket_name(s3_uri):\n    \"\"\"\n    Extract the bucket name from an S3 URI.\n    \n    Args:\n        s3_uri (str): S3 URI in format 's3://bucket-name/key/path'\n    \n    Returns:\n        str: The bucket name\n    \n    Raises:\n        ValueError: If the URI format is invalid\n    \"\"\"\n    if not s3_uri.startswith('s3://'):\n        raise ValueError(\"URI must start with 's3://'\")\n    \n    # Remove 's3://' prefix\n    remainder = s3_uri[5:]\n    \n    # Split by '/' and get the first part (bucket name)\n    bucket_name = remainder.split('/')[0]\n    \n    if not bucket_name:\n        raise ValueError(\"Bucket name cannot be empty\")\n    \n    return bucket_name\n\n\n# Test cases\ntest_cases = [\n    's3://my-bucket/key/path',\n    's3://example-bucket/documents/file.txt',\n    's3://bucket-123/a/b/c/d',\n    's3://simple-bucket/',\n]\n\nfor uri in test_cases:\n    bucket = extract_s3_bucket_name(uri)\n    print(f\"{uri} -> {bucket}\")\n```\n\n**Output:**\n```\ns3://my-bucket/key/path -> my-bucket\ns3://example-bucket/documents/file.txt -> example-bucket\ns3://bucket-123/a/b/c/d -> bucket-123\ns3://simple-bucket/ -> simple-bucket\n```\n\n## Alternative Solutions\n\n**Using regex:**\n```python\nimport re\n\ndef extract_s3_bucket_name(s3_uri):\n    match = re.match(r's3://([^/]+)', s3_uri)\n    if not match:\n        raise ValueError(\"Invalid S3 URI format\")\n    return match.group(1)\n```\n\n**Using urllib:**\n```python\nfrom urllib.parse import urlparse\n\ndef extract_s3_bucket_name(s3_uri):\n    parsed = urlparse(s3_uri)\n    if parsed.scheme != 's3':\n        raise ValueError(\"URI must use 's3' scheme\")\n    return parsed.netloc\n```\n\nAll three approaches work effectively. Choose based on your preference for simplicity, regex familiarity, or URL parsing library usage.",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from an S3 URI in the format 's3://bucket-name/key/path' and extract only the bucket name",
#       "format": "regex"
#     },
#     "score": 7,
#     "reasoning": "The solution correctly solves the stated task with three valid approaches. The string manipulation method is simple and readable, while regex and urllib alternatives are elegant. However, the primary implementation has defensive programming gaps - it doesn't handle None input or validate actual AWS bucket naming constraints. The urllib example has a subtle bug where invalid URIs may not raise errors. Despite these gaps, all approaches work for well-formed inputs and the solution provides good educational value with multiple techniques."
#   },
#   {
#     "output": "# AWS IAM S3 Read-Only Policy\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket/*\"\n    },\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketLocation\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket\"\n    }\n  ]\n}\n```\n\n## Explanation\n\nThis policy grants **read-only access** with two statements:\n\n### Statement 1: Object-Level Access\n- **Actions:**\n  - `s3:GetObject` - Read objects in the bucket\n  - `s3:GetObjectVersion` - Access object versions\n- **Resource:** `arn:aws:s3:::my-data-bucket/*` - All objects in the bucket\n\n### Statement 2: Bucket-Level Access\n- **Actions:**\n  - `s3:ListBucket` - List objects in the bucket\n  - `s3:GetBucketLocation` - Retrieve bucket region\n- **Resource:** `arn:aws:s3:::my-data-bucket` - The bucket itself\n\n**Note:** The second statement is necessary because listing bucket contents requires bucket-level permissions, not object-level permissions.",
#     "test_case": {
#       "task": "Create a JSON object representing an AWS IAM policy that allows read-only access to all objects in an S3 bucket named 'my-data-bucket'",
#       "format": "json"
#     },
#     "score": 8,
#     "reasoning": "The solution correctly addresses the core requirement of read-only S3 access with proper resource targeting and clear explanation. However, it includes s3:GetObjectVersion without justification, which slightly violates least privilege principles. The policy is functional and production-ready for basic read-only scenarios but could be more precisely scoped to actual requirements."
#   },
#   {
#     "output": "# AWS EC2 Instance ID Validator\n\nHere's a Python function that validates AWS EC2 instance ID format:\n\n```python\nimport re\n\ndef is_valid_ec2_instance_id(instance_id: str) -> bool:\n    \"\"\"\n    Validates if a string matches the AWS EC2 instance ID format.\n    \n    Valid format: 'i-' followed by either:\n    - 8 hexadecimal characters (older format)\n    - 17 hexadecimal characters (newer format)\n    \n    Args:\n        instance_id: String to validate\n        \n    Returns:\n        True if the instance_id matches valid EC2 instance ID format, False otherwise\n    \n    Examples:\n        >>> is_valid_ec2_instance_id(\"i-1234abcd\")\n        True\n        >>> is_valid_ec2_instance_id(\"i-1234567890abcdef0\")\n        True\n        >>> is_valid_ec2_instance_id(\"i-invalid\")\n        False\n        >>> is_valid_ec2_instance_id(\"1234abcd\")\n        False\n    \"\"\"\n    pattern = r'^i-[a-f0-9]{8}$|^i-[a-f0-9]{17}$'\n    return bool(re.match(pattern, instance_id))\n```\n\n## Alternative Implementation (without regex)\n\n```python\ndef is_valid_ec2_instance_id(instance_id: str) -> bool:\n    \"\"\"\n    Validates if a string matches the AWS EC2 instance ID format.\n    Non-regex version.\n    \"\"\"\n    # Check if it starts with 'i-'\n    if not instance_id.startswith('i-'):\n        return False\n    \n    # Get the part after 'i-'\n    hex_part = instance_id[2:]\n    \n    # Check if length is 8 or 17\n    if len(hex_part) not in (8, 17):\n        return False\n    \n    # Check if all characters are hexadecimal (0-9, a-f)\n    try:\n        int(hex_part, 16)\n        return True\n    except ValueError:\n        return False\n```\n\n## Test Cases\n\n```python\n# Test the function\ntest_cases = [\n    # Valid cases\n    (\"i-1234abcd\", True),              # 8 hex chars (older format)\n    (\"i-0000000000000000\", True),      # 8 zeros\n    (\"i-ffffffff\", True),              # 8 f's\n    (\"i-1234567890abcdef0\", True),     # 17 hex chars (newer format)\n    (\"i-0000000000000000000\", True),   # 17 zeros\n    (\"i-ffffffffffffffff\", True),      # 17 f's\n    \n    # Invalid cases\n    (\"i-invalid\", False),              # Contains non-hex characters\n    (\"i-12345678\", False),             # Missing 'i-' prefix\n    (\"1234abcd\", False),               # Missing 'i-' prefix\n    (\"i-12345\", False),                # Too few characters (5)\n    (\"i-123456789\", False),            # Wrong length (9)\n    (\"i-1234567890abcdef\", False),     # Wrong length (16)\n    (\"i-1234567890abcdef00\", False),   # Wrong length (18)\n    (\"i-1234abcG\", False),             # Contains invalid character 'G'\n    (\"I-1234abcd\", False),             # Wrong prefix case\n    (\"i_1234abcd\", False),             # Wrong separator\n    (\"\", False),                       # Empty string\n    (\"i-\", False),                     # No hex characters\n]\n\nfor instance_id, expected in test_cases:\n    result = is_valid_ec2_instance_id(instance_id)\n    status = \"\u2713\" if result == expected else \"\u2717\"\n    print(f\"{status} is_valid_ec2_instance_id('{instance_id}') = {result}\")\n```\n\n## Output\n```\n\u2713 is_valid_ec2_instance_id('i",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS EC2 instance ID string and returns True if it matches the valid format (i-followed by 8 or 17 hexadecimal characters)",
#       "format": "python"
#     },
#     "score": 6,
#     "reasoning": "The solution demonstrates good software engineering practices with multiple implementations, comprehensive documentation, and organized test cases. However, it has a critical functional flaw: AWS EC2 instance IDs support both uppercase and lowercase hexadecimal characters, but both implementations only validate lowercase. This means valid instance IDs like 'i-1234ABCD' would incorrectly return False. The test cases compound this issue by not covering uppercase scenarios. A simple fix (adding A-F to the character class or using re.IGNORECASE) would resolve this."
#   }
# ]
